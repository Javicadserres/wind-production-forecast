# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from matplotlib import cm
from sklearn.preprocessing import MinMaxScaler
from pathlib import Path
from model.losses import SmoothPinballLoss
from model.model import LSTM
from data.preprocessing import FrameTorch
from model.trainer import Trainer
from utils import get_scores

torch.manual_seed(0)

# %% [markdown]
# #### Import data and set quantiles

# %%
PATH_DATA = Path.cwd().parent / 'data' / 'files'

data = pd.read_csv((PATH_DATA / 'data.csv'), index_col='time')

# quantiles to predict
quantiles = torch.tensor([0.025, 0.05, 0.1, 0.15, 0.85, 0.9, 0.95, 0.975])

# lookback periods
slide = 56

# %% [markdown]
# ## LSTM USING ONLY THE TARGET

# %%
_data = pd.concat(
    [data['production'], data['production'].shift(-8).copy()], 
    axis=1, 
    keys=['production_shift', 'production']
).dropna()

# %%
# intialize frametorch
frametorch = FrameTorch(_data)
# split data
frametorch.split_data()
# scale data
frametorch.scale_data(method=MinMaxScaler)

# train, val and test loaders
train_loader, val_loader, test_loader = frametorch.data_to_loader(slide=slide)

# %% [markdown]
# #### MODEL PREPARATION

# %%
# number of inputs and outputs
n_inputs = frametorch.data.shape[1] - 1
n_outputs = len(quantiles)

# %%
# model
quantilenet = LSTM(input_size=n_inputs, out_size=n_outputs, hidden_size=n_inputs, n_layers=2)
# criterion to use
criterion = SmoothPinballLoss(quantiles)
# optimizer
optimizer = optim.Adam(quantilenet.parameters(), lr=0.0001)
# trainer class
trainer = Trainer(quantilenet, criterion, optimizer)

# %% [markdown]
# #### TRAIN DE MODEL

# %%
quantilenet = trainer.fit(
    train_loader, val_loader, epochs=2000, n_logger=30, patience=50
)
# Out:
# epoch: 0 train loss: 1.885 val loss: 1.796
# epoch: 30 train loss: 0.848 val loss: 0.775
# epoch: 60 train loss: 0.319 val loss: 0.278
# epoch: 90 train loss: 0.276 val loss: 0.268
# epoch: 120 train loss: 0.273 val loss: 0.271
# epoch: 150 train loss: 0.273 val loss: 0.27
# epoch: 180 train loss: 0.272 val loss: 0.269
# epoch: 210 train loss: 0.271 val loss: 0.267
# epoch: 240 train loss: 0.271 val loss: 0.266
# epoch: 270 train loss: 0.27 val loss: 0.265
# epoch: 300 train loss: 0.27 val loss: 0.265
# epoch: 330 train loss: 0.27 val loss: 0.264
# epoch: 360 train loss: 0.269 val loss: 0.263
# epoch: 390 train loss: 0.268 val loss: 0.262
# epoch: 420 train loss: 0.268 val loss: 0.261
# epoch: 450 train loss: 0.267 val loss: 0.26
# epoch: 480 train loss: 0.267 val loss: 0.259
# epoch: 510 train loss: 0.266 val loss: 0.257
# epoch: 540 train loss: 0.265 val loss: 0.256
# epoch: 570 train loss: 0.264 val loss: 0.255
# epoch: 600 train loss: 0.264 val loss: 0.254
# epoch: 630 train loss: 0.263 val loss: 0.252
# epoch: 660 train loss: 0.262 val loss: 0.251
# epoch: 690 train loss: 0.262 val loss: 0.25
# epoch: 720 train loss: 0.261 val loss: 0.249
# epoch: 750 train loss: 0.26 val loss: 0.248
# epoch: 780 train loss: 0.26 val loss: 0.247
# epoch: 810 train loss: 0.26 val loss: 0.246
# epoch: 840 train loss: 0.259 val loss: 0.245
# epoch: 870 train loss: 0.259 val loss: 0.245
# epoch: 900 train loss: 0.259 val loss: 0.244
# epoch: 930 train loss: 0.259 val loss: 0.244
# epoch: 960 train loss: 0.258 val loss: 0.243
# epoch: 990 train loss: 0.258 val loss: 0.243
# epoch: 1020 train loss: 0.258 val loss: 0.243
# epoch: 1050 train loss: 0.258 val loss: 0.243
# epoch: 1080 train loss: 0.258 val loss: 0.242
# epoch: 1110 train loss: 0.258 val loss: 0.242
# epoch: 1140 train loss: 0.258 val loss: 0.242
# epoch: 1170 train loss: 0.258 val loss: 0.242
# epoch: 1200 train loss: 0.257 val loss: 0.242
# epoch: 1230 train loss: 0.257 val loss: 0.241
# epoch: 1260 train loss: 0.257 val loss: 0.241
# epoch: 1290 train loss: 0.257 val loss: 0.241
# epoch: 1320 train loss: 0.257 val loss: 0.241
# epoch: 1350 train loss: 0.257 val loss: 0.241
# epoch: 1380 train loss: 0.257 val loss: 0.241
# epoch: 1410 train loss: 0.257 val loss: 0.241
# epoch: 1440 train loss: 0.257 val loss: 0.241
# epoch: 1470 train loss: 0.257 val loss: 0.241
# epoch: 1500 train loss: 0.257 val loss: 0.241
# epoch: 1530 train loss: 0.257 val loss: 0.241
# epoch: 1560 train loss: 0.257 val loss: 0.241
# epoch: 1590 train loss: 0.257 val loss: 0.241
# epoch: 1620 train loss: 0.257 val loss: 0.24
# epoch: 1650 train loss: 0.257 val loss: 0.24
# epoch: 1680 train loss: 0.257 val loss: 0.24
# epoch: 1710 train loss: 0.257 val loss: 0.24
# epoch: 1740 train loss: 0.257 val loss: 0.24
# epoch: 1770 train loss: 0.257 val loss: 0.24
# epoch: 1800 train loss: 0.257 val loss: 0.24
# epoch: 1830 train loss: 0.257 val loss: 0.24
# epoch: 1860 train loss: 0.257 val loss: 0.24
# epoch: 1890 train loss: 0.257 val loss: 0.24
# epoch: 1920 train loss: 0.257 val loss: 0.24
# epoch: 1950 train loss: 0.257 val loss: 0.24
# epoch: 1980 train loss: 0.257 val loss: 0.24

# %% [markdown]
# ## LSTM USING ALL DATA

# %%
data['production'] = data['production'].shift(-8)
data = data.dropna()

# %%
data_non_spread = data.drop(data.filter(regex='spread').columns, axis=1)
# intialize frametorch
frametorch_all = FrameTorch(data_non_spread)
# split data
frametorch_all.split_data()
# scale data
frametorch_all.scale_data(method=MinMaxScaler)

# train, val and test loaders
train_loader, val_loader, test_loader = frametorch_all.data_to_loader(slide=slide)

# %% [markdown]
# #### MODEL PREPARATION

# %%
# number of inputs and outputs
n_inputs = frametorch_all.data.shape[1] - 1
n_outputs = len(quantiles)

# %%
# model
quantilenet_all = LSTM(input_size=n_inputs, out_size=n_outputs, hidden_size=slide, n_layers=2)
# criterion to use
criterion = SmoothPinballLoss(quantiles)
# optimizer
optimizer = optim.Adam(quantilenet_all.parameters(), lr=0.0003)
# trainer class
trainer_all = Trainer(quantilenet_all, criterion, optimizer)

# %% [markdown]
# #### TRAIN DE MODEL

# %%
quantilenet_all = trainer_all.fit(
    train_loader, val_loader, epochs=2000, n_logger=30, patience=200
)
# Out:
# epoch: 0 train loss: 0.394 val loss: 0.268
# epoch: 30 train loss: 0.274 val loss: 0.265
# epoch: 60 train loss: 0.264 val loss: 0.267
# epoch: 90 train loss: 0.244 val loss: 0.309
# epoch: 120 train loss: 0.221 val loss: 0.319
# epoch: 150 train loss: 0.191 val loss: 0.339
# epoch: 180 train loss: 0.167 val loss: 0.419
# epoch: 210 train loss: 0.171 val loss: 0.465
# epoch: 240 train loss: 0.123 val loss: 0.578
# epoch: 270 train loss: 0.114 val loss: 0.647
# epoch: 300 train loss: 0.103 val loss: 0.664
# epoch: 330 train loss: 0.098 val loss: 0.647
# epoch: 360 train loss: 0.08 val loss: 0.697
# epoch: 390 train loss: 0.105 val loss: 0.649
# epoch: 420 train loss: 0.072 val loss: 0.727

# %% [markdown]
# ## COMPARE MODELS

# %%
train_loader, val_loader, test_loader = frametorch.data_to_loader(slide=slide)

# validation input and target
inputs, target = val_loader.dataset.inputs, val_loader.dataset.target
y_test = pd.Series(target.squeeze().tolist())

# quantilenet predictions
y_pred_quantilenet = quantilenet(inputs)
y_preds_quantilenet = pd.DataFrame(y_pred_quantilenet.tolist())

# %% [markdown]
# Predictions without spread

# %%
train_loader, val_loader, test_loader = frametorch_all.data_to_loader(slide=slide)

# validation input and target
inputs, _ = val_loader.dataset.inputs, val_loader.dataset.target

# quantilenet predictions
y_pred_quantilenet_all = quantilenet_all(inputs)
y_preds_quantilenet_all = pd.DataFrame(y_pred_quantilenet_all.tolist())

# %% [markdown]
# ### COMPARE MODEL TYPES

# %% [markdown]
# Convergence

# %%
loss_ss = pd.Series(trainer.train_losses[1:])
validations_losses_ss = pd.Series(trainer.val_losses)

loss_ss_all = pd.Series(trainer_all.train_losses[1:])
validations_losses_ss_all = pd.Series(trainer_all.val_losses)

fig, ax = plt.subplots(ncols=2, figsize=(15, 5), sharey=True)

loss_ss.plot(ax=ax[0])
loss_ss_all.plot(ax=ax[0])
validations_losses_ss.plot(ax=ax[1])
validations_losses_ss_all.plot(ax=ax[1])

ax[0].set_ylabel('Loss')
ax[0].set_title('Train Loss per epoch')
ax[0].legend(['Only target', 'All data'])
ax[0].grid()

ax[1].set_title('Validation Loss per epoch')
ax[1].legend(['Only target', 'All data'])
ax[1].grid()

# %% [markdown]
# Scores

# %%
quantilenet_scores = get_scores(y_pred_quantilenet, target, quantiles)
quantilenet_all_scores = get_scores(y_pred_quantilenet_all, target[:-1], quantiles)

final_scores = pd.concat(
    [quantilenet_scores, quantilenet_all_scores], axis=1, keys=['Only target', 'All data']
)
final_scores
# Out:
#            Only target   All data
# QS            0.227176   0.686905
# IS            0.754362   3.023752
# Sharpnees     0.690575   0.209814
# ACE           4.412623  53.511691

# %% [markdown]
# Plots

# %%
viridis = cm.get_cmap('viridis', len(quantiles))
fig, ax = plt.subplots(ncols=2, figsize=(20, 5), sharey=True)

for i in range(len(y_preds_quantilenet_all.columns)-1):
    ax[0].fill_between(
        y_preds_quantilenet_all.index[:200], 
        y_preds_quantilenet_all[i][:200], 
        y_preds_quantilenet_all[i+1][:200], 
        color=viridis.colors[i]
    )  
y_test[:200].plot(color='red', ax=ax[0])
ax[0].set_title('Predictions using all data')
ax[0].grid()

for i in range(len(y_preds_quantilenet.columns)-1):
    ax[1].fill_between(
        y_preds_quantilenet.index[:200], 
        y_preds_quantilenet[i][:200], 
        y_preds_quantilenet[i+1][:200], 
        color=viridis.colors[i]
    )
y_test[:200].plot(color='red', ax=ax[1])
ax[1].set_title('Predictions with just the label as an input')
ax[1].grid()
